# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
transformed_data_2 = pd.read_csv("transformed_housing_data_2.csv")

# %%
transformed_data_2 .head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
# seperating dependent variable (Y) & independent variable (X)
# will use 'iloc' function to Defining the Variables
Y = transformed_data_2.iloc[:, 0] #0 : as sale price is the 0th element of our columns
X = transformed_data_2.iloc[:, 1:31]

# %%
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0               3             1.00               1180.0              5650.0
# 1               3             2.25               2570.0              7242.0
# 2               2             1.00                770.0             10000.0
# 3               4             3.00               1960.0              5000.0
# 4               3             2.00               1680.0              8080.0
#
#    No of Floors  No of Times Visited  Overall Grade  \
# 0           1.0                    0              7
# 1           2.0                    0              7
# 2           1.0                    0              6
# 3           1.0                    0              7
# 4           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# ...

# %%
# lets split them in train and test data
from sklearn.model_selection import train_test_split

# %%
# we will be having 2 new sets for both X & Y [70% : Train Data & 30% : Test Data]
X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size = 0.3)

# %%
X_train.shape #for finding out the dimensions
# Out:
# (15126, 30)

# %%
X_test.shape
# Out:
# (6483, 30)

# %%
Y_train.shape
# Out:
# (15126,)

# %% [markdown]
# # Feature Scalling

# %%
X.describe()
# Out:
#        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# count    21609.000000     21609.000000         21609.000000
# mean         3.370771         2.114709          2079.872553
# std          0.929916         0.770097           918.347816
# min          0.000000         0.000000           290.000000
# 25%          3.000000         1.750000          1430.000000
# 50%          3.000000         2.250000          1910.000000
# 75%          4.000000         2.500000          2550.000000
# max         33.000000         8.000000         13540.000000
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# count        2.160900e+04  21609.000000         21609.000000   21609.000000
# mean         1.510641e+04      1.494215             0.234347       7.623490
# std          4.142353e+04      0.539909             0.766382       1.105519
# min          5.200000e+02      1.000000             0.000000       1.000000
# ...

# %% [markdown]
# # Standardisasion

# %%
from sklearn import preprocessing
scale = preprocessing.StandardScaler()

# %%
# fitting and transforming the data for 'X_train' which contains all the features of train dataset
X_train = scale.fit_transform(X_train)

# %%
X_train # has been converted into an array
# Out:
# array([[-1.45510592, -1.45367248, -1.25383882, ..., -0.10661461,
#         -0.16837455, -0.04675943],
#        [ 0.67619379,  0.17479727,  0.19792748, ..., -0.10661461,
#         -0.16837455, -0.04675943],
#        [ 0.67619379,  0.82618517,  1.1148325 , ..., -0.10661461,
#         -0.16837455, -0.04675943],
#        ...,
#        [-0.38945606, -0.15089668, -0.60982219, ..., -0.10661461,
#         -0.16837455, -0.04675943],
#        [-0.38945606, -0.80228458, -0.45700469, ..., -0.10661461,
#          5.93913978, -0.04675943],
#        [ 0.67619379,  0.82618517, -0.00946771, ..., -0.10661461,
#          5.93913978, -0.04675943]])

# %%
# scalling the features of 'test dataset'
X_test = scale.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 0.67812424,  0.17774066,  0.33281155, ..., -0.12452919,
#         -0.16995383, -0.05127511],
#        [ 0.67812424, -1.43340681, -0.85839201, ..., -0.12452919,
#         -0.16995383, -0.05127511],
#        [-0.42122046,  0.49997015,  0.64685612, ..., -0.12452919,
#         -0.16995383, -0.05127511],
#        ...,
#        [-0.42122046, -1.43340681, -0.55517656, ..., -0.12452919,
#         -0.16995383, -0.05127511],
#        [-0.42122046, -1.43340681, -1.15077834, ..., -0.12452919,
#         -0.16995383, -0.05127511],
#        [ 0.67812424,  0.17774066, -0.08952426, ..., -0.12452919,
#         -0.16995383, -0.05127511]])

# %%
transformed_data_2 # this scaled data will be used in final model building module
# Out:
#        Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0        221900.0               3             1.00               1180.0
# 1        538000.0               3             2.25               2570.0
# 2        180000.0               2             1.00                770.0
# 3        604000.0               4             3.00               1960.0
# 4        510000.0               3             2.00               1680.0
# ...           ...             ...              ...                  ...
# 21604    360000.0               3             2.50               1530.0
# 21605    400000.0               4             2.50               2310.0
# 21606    402101.0               2             0.75               1020.0
# 21607    400000.0               3             2.50               1600.0
# 21608    325000.0               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# ...
